# %% [markdown]
# <a href="https://colab.research.google.com/github/LeticiaS98/Estrutura_de_Dados/blob/main/Estrutura_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
# # **1.1 Python** 🐍
# ---

# %% [markdown]
# &emsp;A linguagem que vai ser utilizada será o Python. Uma linguagem de *script * de alto nível, de tipagem forte e dinâmica. Além de possuir uma sintaxe clara e legível que é ótima tanto para iniciantes como para desenvolvedores mais experientes.
# <br>
#
#
# >**ESTRUTURA DA LINGUAGEM**
# --
#
# - ✅**Indentação:**
#
#   Python usa indentação (espaços em branco) para definir blocos de código (em vez de chaves, como em outras linguagens). Isso torna o código Python mais legível e organizado.
# <br>
#
# - ✅**Tipagem Dinâmica:**
#
#   Significa que não precisa declarar o tipo de uma variável explicitamente. O interpretador Python infere o tipo da variável em tempo de execução.
# <br>
#
# - ✅**Bibliotecas Padrão:**
#   Oferece uma ampla gama de módulos e funções para diversas tarefas, como manipulação de arquivos, redes, processamento de texto e muito mais.
# <br>
#
# - ✅**Interpretada:**
#
#   Python é uma linguagem interpretada, o que significa que o código é executado linha por linha pelo interpretador, sem a necessidade de compilação prévia.
# <br>
#
# &emsp;O python possui dois tipos de dados: Bult-in e estruturas definidas pelo o **us**uário:
# - ***Bulit-in*** → Listas, Dícionarios, Tuplas, Conjunto.
# -**Definidas Pelo o usuário** → Listas encadeadas, Filas, Árvores, Grafos, Hashmap
# <br>
#
# <br>
#
# >ℹ️ **Curiosidades importantes**.
# <br>
# - Em computação, a unidade básica de armazenamento é o bit.
# <br>
# - No sistema de numeração binária, um conjunto de 8 bits forma 1 byte. (2^8 = 256 valores → byte)

# %% [markdown]
# ---
# # **2.1 ESTRUTURA DE DADOS** 🗂️
# ---

# %% [markdown]
# &emsp;A disciplina de **Estruturas de Dados** é uma das mais importantes na programação, pois ensina como organizar, armazenar e manipular **Dados** de forma eficiente e um programa. Ela faz parte da base da ciência da computação e é fundamental para desenvolver software rápido e otimizado. São um conceito fundamental em ciência da computação e são usadas em uma ampla variedade de aplicações, desde sistemas operacionais e bancos de dados até aplicativos de jogos e inteligência artificial.
# <br>
# <br>
#
# ---
#
# >📌**LINEARES**
#
# São estruturas de dados que têm seus elementos organizados d forma **sequencial**, ou seja, cada elemento tem um antecessor e um sucessor (exceto o primeiro e o último).
# <br>
# - ✔ Arrays (Vetores e Matrizes)
# - ✔ Listas Ligadas
# - ✔ Pilhas (Stacks)
# - ✔ Filas (Queues)
# <br>
# <br>
#
# ---
#
# >📌**ESTÁTICAS**
#
# Estruturas de dados que têm seu tamanho **fixo definido na sua criação**, ou seja, não pode ser alterado durante a execução do programa.
# <br>
# - ✔ Arrays
# - ✔ Tuplas
# <br>
#
# |🔥 Vantagens|❌ Desvantagens|
# |:---|:---|
# |Acesso rápidoaos<br> elementos (O(1)).|	O tamanho não pode ser alterado.|
# |Menos uso de ponteiros<br>(reduz erros).|	Pode desperdiçar memória se o tamanho for muito grande.|
# |Melhor controle da<br>memória (não há realocação).|Difícil de gerenciar se os dados forem dinâmicos.|
# <br>
#
# As estruturas estáticas são úteis quando o número de elementos é conhecido antecipadamente. No entanto, se houver a necessidade de redimensionamento, é melhor usar estruturas **dinâmicas**, como listas ligadas ou vetores dinâmicos (List em Python, ArrayList em Java).
# <br>
# <br>
#
# ---
#
# >📌**Ñ LINEARES**
#
# São aquelas em que os elementos **Não seguem uma seguência única** na memória, permitindo **múltiplas conexões** entre os elementos. Elas são ideais para representar **relações complexas** entre dados, como hierarquias e redes.
#
#
# |Característica|Lineares|Não Lineares|
# |:---|:-----|:-----|
# |Organização|Sequencial|Conexões| complexas|
# |Acesso|Simples e direto|Pode exigir busca|
# |Flexibilidade|Estruturas mais rígidas|	Modelam relações mais livres|
# |Aplicações|Estruturas simples e diretas| Modelagem de redes e hierarquias|
#
# >ℹ️ As estruturas não lineares são essenciais quando os dados possuem relações mais complexas do que apenas uma sequência.
# <br>
# - Use Árvores para representar hierarquias.
# <br>
# <br>
# - Use Grafos para modelar redes e conexões.
# <br>
# <br>
# -Use Tabelas Hash para buscas rápidas e armazenamento eficiente.
# <br>
# <br>
#
# ---
#
# >📌**DINÂMICAS**
#
# São aquelas que podem crescer e diminuir conforme necessário durante a execução do programa. Elas **utilizam alocação dinâmica de memória**, permitindo maior flexibilidade e eficiência no uso dos recursos. Ideais para situações onde o número de elementos não é fixo.
#
# |Estrutura|Características|Vantagens|Desvantagens|
# |:--|:--:|:--:|:--:|
# |Listas<br>Ligadas|Conjunto de nós ligados por ponteiros|Tamanho variável, fácil inserção/remoção|Acesso sequencial lento|
# |Filas<br>Dinâmicas|Seguem o princípio FIFO| Cresce conforme necessário|Pode consumir mais memória|
# |Pilhas<br>Dinâmicas|Seguem o princípio LIFO|Ótima para controle de chamadas e backtracking|Requer controle de memória|
# |Árvores|Estrutura hierárquica com nós conectados|Organiza dados de forma eficiente|Pode exigir balanceamento|
# |Grafos|Representam conexões entre elementos|Modelam relações complexas|Implementação pode ser complexa|

# %% [markdown]
# ---
# # **2.2 Por que são importantes**
# ---

# %% [markdown]
# - ✅**Eficiência:**
#
#    Ajuda a escrever código mais rápido e econômico em memória.
# <br>
#
# - ✅**Organização:**
#
#    Fornecem uma maneira de organizar os dados de forma lógica e coerente, o que facilita o desenvolvimento e a manutenção de software.
# <br>
#
# - ✅**Escaláveis:**
#
#   Sistemas como redes sociais, motores de busca e bancos de dados dependem dessas estruturas para processar bilhões de dados.
# <br>
#
# - ✅**Reutilização**:
#
#   As estruturas de dados podem ser reutilizadas em diferentes programas, o que economiza tempo e esforço de desenvolvimento.
# <br>
#
# - ✅**Entrevistas de Emprego:**
#
#   Muitas empresas de tecnologia exigem conhecimento de estruturas de dados para testes técnicos.

# %% [markdown]
# ---
# # **2.3 Tipos comuns de estruturas de dados:**
# ---

# %% [markdown]
# |ESTRUTURA|✍|
# |:--|:--|
# |Array|São listas organizadas de elementos do mesmo tipo, acessados por um índice.|
# |Listas Ligadas|Uma sequência de elementos conectados por ponteiros, permitindo inserções e remoções mais eficientes do que arrays.|
# |Pilhas (Stacks)|Estrutura do tipo LIFO (Last In, First Out – o último a entrar é o primeiro a sair). Exemplo: um monte de pratos empilhados.|
# |Filas (Queues)|Segue o princípio FIFO (First In, First Out – o primeiro a entrar é o primeiro a sair). Exemplo: fila de banco.|
# |Filas de Prioridade<br>e Heaps|Variantes das filas onde os elementos têm prioridades diferentes.|
# |Tabelas Hash|Estrutura que permite buscas muito rápidas usando chaves e valores.|
# |Grafos|Estruturas usadas para representar redes, como mapas, conexões sociais e rotas de entrega.|
# <br>
#
# |ÁVORES|✍|
# |:---|:---|
# |Árvore Binária|Cada nó tem no máximo dois filhos (esquerdo e direito).Amplamente utilizada em algoritmos de busca e ordenação.|
# |Árvore Balanceada|Árvores binárias que mantêm o equilíbrio para garantir busca eficiente. P/busca rápida e consistente|
# |Árvore B-Trees|Otimizadas para armazenamento em disco, com múltiplos filhos por nó. Exemplo: índices de bancos de dados.|

# %% [markdown]
# ---
# ## **2.4 ARRAY (Vetor e Matriz)**🔢
# ---

# %% [markdown]
# &emsp;Um **array** (ou vetor \ matriz) é uma estrutura de dados **linear** e **estática**que armazena elementos do **mesmo tipo** em posições consecutivas da memória. Útil quando precisamos armazenar e acessar múltiplos valores rapidamente.
#
# >💭&emsp; **Exemplo:**
# <br>Pense em uma fila de cadeiras numeradas em um cinema. Cada cadeira representa um elemento do array e pode ser acessada pelo seu número (índice).
# <br>
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# >📌**Características do Array**
# --
# - ✅Homogeneidade: Todos os elementos do array são do mesmo tipo.
#
# - ✅Acesso Rápido: O acesso a um elemento é feito diretamente pelo índice, o que o torna muito eficiente.
#
# - ✅Tamanho Fixo: Em algumas linguagens (como C e Java), o tamanho do array é fixo e definido na criação. Em Python, as listas são flexíveis e podem crescer dinamicamente.
#
# >📌**Conceitos Fundamentais:**
# --
#
# - **Elementos:** Cada valor armazenado no array é chamado de elemento.
#
# - **Índices:** Cada elemento do array possui um índice, que é um número inteiro que representa sua posição na lista. Na maioria das linguagens de programação, os índices começam em 0.
#
# - **Tipo de Dados:** Em geral, os arrays armazenam elementos do mesmo tipo de dado (inteiros, strings, etc.).
#
# - **Tamanho Fixo:** Em arrays estáticos, o tamanho é definido na criação e não pode ser alterado. Já os arrays dinâmicos podem crescer ou diminuir conforme necessário.
#
# >📌 **Tipos de Arrays**
# --
# 1. **Array Unidimensional** (Vetor): Uma lista de elementos em uma única linha.
# <br>
# 2. **Array Multidimensional** (Matriz): Uma tabela com várias linhas e colunas.
#
# ---
#
# **➡️ Exemplo de Array em Python**
# --

# %% [markdown]
# **1️⃣ Array Unidimensional (Vetor)**
# --
#
# >**Obs**: Em Python, usamos listas para representar arrays,
# pois elas são mais flexíveis.

# %%
# Criando um array (lista) de números
numeros = [10, 20, 30, 40, 50]

# Acessando elementos pelo índice
print(numeros[0])  # Saída: 10
print(numeros[2])  # Saída: 30

# Modificando um elemento
numeros[1] = 25
print(numeros)  # Saída: [10, 25, 30, 40, 50]
# Out:
# 10
# 30
# [10, 25, 30, 40, 50]
# '\nObs: Em Python, usamos listas para representar arrays,\npois elas são mais flexíveis.\n'

# %% [markdown]
# **2️⃣ Array Bidimensional (Matriz)**
# --
#
# >**Dica:** Matrizes são úteis para representar tabuleiros de jogos, imagens e dados organizados em tabelas.

# %%
# Criando uma matriz 3x3 (3 linhas e 3 colunas)
matriz = [
    [1, 2, 3],
    [4, 5, 6],
    [7, 8, 9]
]

# Acessando um elemento (linha 1, coluna 2)
print(matriz[1][2])  # Saída: 6

# Modificando um elemento
matriz[0][1] = 99
print(matriz)
# Out:
# 6
# [[1, 99, 3], [4, 5, 6], [7, 8, 9]]

# %% [markdown]
# ➡️ **Operações Básicas**
# --
# >Usando o Módulo array (Para tipos específicos de dados)

# %%
import array

"""
1️⃣ Criando um Array
"""
# 'i' indica números inteiros
arr = array.array('i', [10, 20, 30, 40, 50])
print('Criando um Array:\n',arr)  # Saída: array('i', [10, 20, 30, 40, 50])

"""
2️⃣Acessando Elementos
"""
print('Acessando Primeiro elemento:\n',arr[0])  # Primeiro elemento → Saída: 10
print('Acessando Terceiro elemento:\n',arr[2])  # Terceiro elemento → Saída: 30
print('Acessando Terceiro elemento:\n',arr[-1]) # Último elemento → Saída: 50


"""
3️⃣Modificando Elementos
"""
arr[1] = 25
print('\nModificando Elementos:\n',arr)  # Saída: array('i', [10, 25, 30, 40, 50])


"""
4️⃣Adicionando Elementos
"""
# append() - Adiciona no final
arr.append(60)
print('\nAdicionando Elementos (append())\n',arr)  # Saída: [10, 25, 99, 40, 50, 60]


# insert() - Insere em uma posição específica
arr.insert(3, 99)
print('\nAdicionando Elementos (insert())\n',arr)  # Saída: [10, 25, 99, 40, 99, 50, 60]


"""
5️⃣Removendo Elementos
"""
# remove() - Remove um valor específico
arr.remove(99)
print('\nRemovendo Elementos (remove(99)):\n',arr)  # Saída: [10, 25, 40, 99, 50, 60]

# pop() - Remove e retorna o último elemento (ou o de um índice específico)
ultimo = arr.pop()
print('\nRemovendo Elementos pop()\n',ultimo)  # Saída: 60
print(arr)  # Saída: [10, 25, 40, 99, 50]


"""
6️⃣Tamanho do Array
"""
print('\nTamanho do Array:',len(arr))  # Saída: 5


"""
7️⃣Percorrendo o Array
"""
for elemento in arr:
    print('\nPercorrendo o Array:',elemento)


"""
8️⃣Concatenando Arrays
"""
arr2 = array.array('i', [70, 80, 90])
arr3 = arr + arr2
print(arr3)


"""
9️⃣Verificando a Existência de um Elemento
"""
print('\nVerificando a Existência de um Elemento')
if 40 in arr:
    print("40 está no array")
# Out:
# Criando um Array:
#  array('i', [10, 20, 30, 40, 50])
# Acessando Primeiro elemento:
#  10
# Acessando Terceiro elemento:
#  30
# Acessando Terceiro elemento:
#  50
#
# Modificando Elementos:
#  array('i', [10, 25, 30, 40, 50])
#
# Adicionando Elementos (append())
#  array('i', [10, 25, 30, 40, 50, 60])
#
# Adicionando Elementos (insert())
#  array('i', [10, 25, 30, 99, 40, 50, 60])
#
# Removendo Elementos (remove(99)):
#  array('i', [10, 25, 30, 40, 50, 60])
#
# Removendo Elementos pop()
#  60
# array('i', [10, 25, 30, 40, 50])
#
# Tamanho do Array: 5
#
# Percorrendo o Array: 10
#
# Percorrendo o Array: 25
#
# Percorrendo o Array: 30
#
# Percorrendo o Array: 40
#
# Percorrendo o Array: 50
# array('i', [10, 25, 30, 40, 50, 70, 80, 90])
#
# Verificando a Existência de um Elemento
# 40 está no array
